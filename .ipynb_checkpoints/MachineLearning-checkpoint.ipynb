# %% [markdown]
# # Machine Learning
# ## WAR정보를 사용하고
# ## WAR정보가 없는 경우는 0으로 채워주고
# ## Logistic model을 사용하는 경우 승무패 예측율 0.55%이상을 얻을 수 있다

# %%
#승무패를 처리하는 result_fnc0, 승1패를 처리하는 result_fnc1
from BaseballGameResult import result_fnc0, result_fnc1
#1차 모델링 WAR정보가 없는 경우 0 
import pandas as pd
game_war = pd.read_csv('game_war.csv', encoding='cp949')

game_score = pd.read_csv('game_score.csv', encoding = 'cp949', header=None)
game_score.columns = ['경기', '결과']

df = pd.merge(game_war, game_score , on='경기' )
df['결과'] = df.결과.apply(lambda x: int(x.split(':')[0])-int(x.split(':')[1]) )
#승1패
#df['결과'] = df.결과.apply(result_fnc1)
#승무패
df['결과'] = df.결과.apply(result_fnc0)

y = df.결과
x = df.drop(['경기','결과', 'Unnamed: 0'], axis=1)


from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y)

from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C=100, max_iter=1000)
lr.fit(x_train, y_train)
pred = lr.predict(x_test)


from sklearn.metrics import classification_report
report = classification_report(y_test, pred)

#overfit
pred_over_fit = lr.predict(x_train)
report_over_fit = classification_report(y_train, pred_over_fit)

print(report)
print(report_over_fit)
# Out:
#               precision    recall  f1-score   support
#
#         away       0.58      0.32      0.42       191
#         home       0.57      0.80      0.67       219
#         near       0.00      0.00      0.00         4
#
#     accuracy                           0.57       414
#    macro avg       0.39      0.38      0.36       414
# weighted avg       0.57      0.57      0.55       414
#
#               precision    recall  f1-score   support
#
#         away       0.58      0.36      0.45       551
#         home       0.59      0.79      0.68       674
#         near       0.00      0.00      0.00        16
#
#     accuracy                           0.59      1241
#    macro avg       0.39      0.38      0.37      1241
# weighted avg       0.58      0.59      0.57      1241
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#승무패를 처리하는 result_fnc0, 승1패를 처리하는 result_fnc1
from BaseballGameResult import result_fnc0, result_fnc1
#2차 모델링 WAR정보가 없는 경우 0, WAR이 0이하면 0
import pandas as pd
game_war0 = pd.read_csv('game_war_0.csv', encoding='cp949')
#print(game_war)
game_score = pd.read_csv('game_score.csv', encoding = 'cp949', header=None)
game_score.columns = ['경기', '결과']
#print(game_score)
df = pd.merge(game_war0, game_score , on='경기' )
df['결과'] = df.결과.apply(lambda x: int(x.split(':')[0])-int(x.split(':')[1]) )


#승1패
#df['결과'] = df.결과.apply(result_fnc1)
#승무패
df['결과'] = df.결과.apply(result_fnc0)

y = df.결과
x = df.drop(['경기','결과', 'Unnamed: 0'], axis=1)
print(x.head(10))
print(y.head(10))
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y)

from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C=100, max_iter=1000)
lr.fit(x_train, y_train)
pred = lr.predict(x_test)


from sklearn.metrics import classification_report
report = classification_report(y_test, pred)

#overfit
pred_over_fit = lr.predict(x_train)
report_over_fit = classification_report(y_train, pred_over_fit)

print(report)
print(report_over_fit)
# Out:
#    away_ 1루수  away_ 2루수  away_ 3루수  away_ 우익수  away_ 유격수  away_ 좌익수  \
# 0    0.69407    0.11464    1.11084    0.69946    0.40134    0.61456
# 1    0.68848    0.26816    1.38679    1.00145    0.74661    0.00000
# 2    0.00000    1.21605    0.00000    0.94987    0.08619    0.00000
# 3    1.39404    0.14901    0.00000    0.50141    0.13434    1.42570
# 4    0.52313    0.00000    1.02483    0.36032    1.07772    0.54402
# 5    0.02842    0.96353    0.00000    0.00000    0.00000    0.00000
# 6    1.27443    0.48717    0.00000    1.43790    1.10139    0.06452
# 7    0.69407    0.41890    0.11464    0.69946    0.40134    0.61456
# 8    0.52313    0.00000    1.02483    0.36032    1.07772    0.54402
# 9    0.02842    0.96353    0.00000    0.00000    0.00000    0.62721
#
#    away_ 중견수  away_ 투수  away_ 포수  away_1번타자  ...  home_ 포수  home_1번타자  \
# 0    0.02062   0.00000   0.00000    0.61456  ...   0.00000    0.61456
# 1    0.56499   0.80189   0.47777    0.00000  ...   0.47777    0.00000
# 2    0.21763   0.00000   0.00000    0.00000  ...   0.00000    0.00000
# 3    0.00000   1.24115   0.54318    0.50141  ...   0.54318    0.50141
# 4    0.00000   0.00000   0.48617    0.00000  ...   0.48617    0.00000
# 5    0.00000   0.17787   0.00000    0.00000  ...   0.00000    0.00000
# 6    0.55577   0.22578   0.00186    0.06452  ...   0.00186    0.06452
# 7    0.02062   0.39605   0.00000    0.61456  ...   0.00000    0.61456
# 8    0.00000   0.36074   0.48617    0.00000  ...   0.48617    0.00000
# 9    0.00000   0.36074   0.00000    0.00000  ...   0.00000    0.00000
#
#    home_2번타자  home_3번타자  home_4번타자  home_5번타자  home_6번타자  home_7번타자  \
# 0    0.02062    0.69946    0.69407    0.47683    1.11084    0.40134
# 1    0.00000    1.38679    1.00145    0.68848    0.47777    0.56499
# 2    0.21763    0.94987    1.09069    1.21605    0.00000    0.08619
# 3    0.00000    1.39404    1.42570    0.33869    0.00000    0.14901
# 4    0.54402    0.13763    0.36032    1.02483    0.52313    0.48617
# 5    0.00000    0.96353    0.18741    0.00000    0.02842    0.00000
# 6    0.55577    1.43790    1.27443    0.48717    1.10139    0.65214
# 7    0.41890    0.69946    0.69407    0.47683    0.02062    0.40134
# 8    0.54402    0.13763    0.36032    1.02483    0.52313    0.48617
# 9    0.00000    0.96353    0.18741    0.00000    0.02842    0.62721
#
#    home_8번타자  home_9번타자
# 0    0.11464    0.00000
# 1    0.26816    0.74661
# 2    0.00000    0.00000
# 3    0.54318    0.13434
# 4    1.07772    0.00000
# 5    0.00000    0.00000
# 6    0.00000    0.00186
# 7    0.11464    0.00000
# 8    1.07772    0.00000
# 9    0.00000    0.00000
#
# [10 rows x 36 columns]
# 0    away
# 1    home
# 2    home
# 3    home
# 4    away
# 5    away
# 6    away
# 7    away
# 8    away
# 9    home
# Name: 결과, dtype: object
#               precision    recall  f1-score   support
#
#         away       0.55      0.34      0.42       188
#         home       0.56      0.77      0.65       218
#         near       0.00      0.00      0.00         8
#
#     accuracy                           0.56       414
#    macro avg       0.37      0.37      0.35       414
# weighted avg       0.54      0.56      0.53       414
#
#               precision    recall  f1-score   support
#
#         away       0.55      0.34      0.42       554
#         home       0.58      0.78      0.67       675
#         near       0.00      0.00      0.00        12
#
#     accuracy                           0.57      1241
#    macro avg       0.38      0.37      0.36      1241
# weighted avg       0.56      0.57      0.55      1241
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#승무패를 처리하는 result_fnc0, 승1패를 처리하는 result_fnc1
from BaseballGameResult import result_fnc0, result_fnc1
#3차 모델링 WPA정보가 없는 경우 0
import pandas as pd
game_wpa = pd.read_csv('game_wpa.csv', encoding='cp949')
#print(game_war)
game_score = pd.read_csv('game_score.csv', encoding = 'cp949', header=None)
game_score.columns = ['경기', '결과']
#print(game_score)
df = pd.merge(game_wpa, game_score , on='경기' )
df['결과'] = df.결과.apply(lambda x: int(x.split(':')[0])-int(x.split(':')[1]) )

#승1패
#df['결과'] = df.결과.apply(result_fnc1)
#승무패
df['결과'] = df.결과.apply(result_fnc0)

y = df.결과
x = df.drop(['경기','결과', 'Unnamed: 0'], axis=1)
print(x.head(10))
print(y)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y)

from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C=100, max_iter=1000)
lr.fit(x_train, y_train)
pred = lr.predict(x_test)


from sklearn.metrics import classification_report
report = classification_report(y_test, pred)

#overfit
pred_over_fit = lr.predict(x_train)
report_over_fit = classification_report(y_train, pred_over_fit)

print(report)
print(report_over_fit)
# Out:
#    away_ 1루수  away_ 2루수  away_ 3루수  away_ 우익수  away_ 유격수  away_ 좌익수  \
# 0       1.72       0.50      -0.92       1.04      -0.20      -0.11
# 1       1.09       0.36      -0.76       0.01      -0.47      -0.07
# 2       0.35       0.80       0.29       0.45       0.72       0.11
# 3       1.09       0.36      -0.76       0.01      -0.47      -0.07
# 4       0.35       0.80       0.29       0.45       0.72       0.11
# 5       1.09       0.36      -0.76       0.01      -0.47      -0.07
# 6       0.69       1.08       0.36      -0.06       0.55       0.12
# 7       1.09       0.36      -0.14       0.78      -0.47      -0.07
# 8       1.09       0.36      -0.14       0.78      -0.47      -0.07
# 9       0.30       0.01       0.96      -0.28       0.16       0.82
#
#    away_ 중견수  away_ 투수  away_ 포수  away_1번타자  ...  home_ 포수  home_1번타자  \
# 0       0.56       0.0      0.02       0.50  ...      0.02       0.50
# 1       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 2       0.59       0.0     -0.31       0.80  ...     -0.31       0.80
# 3       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 4       0.59       0.0     -0.31       0.80  ...     -0.31       0.80
# 5       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 6       0.43       0.0     -0.03       0.05  ...     -0.03       0.05
# 7       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 8       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 9      -0.03       0.0      0.00       0.01  ...      0.00       0.01
#
#    home_2번타자  home_3번타자  home_4번타자  home_5번타자  home_6번타자  home_7번타자  \
# 0       0.56       1.04       1.72      -0.41      -0.92       0.02
# 1      -0.76       0.79       0.73       1.09      -0.07      -0.47
# 2       0.11       0.59       0.35       0.72       0.29      -0.42
# 3      -0.76       0.79       0.73       1.09      -0.07      -0.47
# 4       0.11       0.59       0.35       0.72       0.29       0.45
# 5      -0.76       0.79       0.73       1.09      -0.07      -0.47
# 6      -0.06       1.08       0.69       0.43       0.12       0.55
# 7       0.78       0.79       0.73       1.09      -0.07      -0.47
# 8       0.78       0.79       0.73       1.09      -0.07      -0.47
# 9      -0.28       0.30       0.82       0.96       0.64      -0.03
#
#    home_8번타자  home_9번타자
# 0      -0.20      -0.11
# 1       0.23       0.01
# 2       0.45      -0.31
# 3       0.23       0.01
# 4       0.33      -0.31
# 5       0.23       0.01
# 6       0.36      -0.03
# 7      -0.14       0.23
# 8      -0.14       0.23
# 9       0.00       0.16
#
# [10 rows x 36 columns]
# 0       home
# 1       away
# 2       away
# 3       home
# 4       home
#         ...
# 2347    away
# 2348    away
# 2349    away
# 2350    home
# 2351    away
# Name: 결과, Length: 2352, dtype: object
#               precision    recall  f1-score   support
#
#         away       0.43      0.20      0.27       266
#         home       0.53      0.78      0.63       314
#         near       0.00      0.00      0.00         8
#
#     accuracy                           0.51       588
#    macro avg       0.32      0.33      0.30       588
# weighted avg       0.47      0.51      0.46       588
#
#               precision    recall  f1-score   support
#
#         away       0.52      0.25      0.34       789
#         home       0.56      0.81      0.66       955
#         near       0.00      0.00      0.00        20
#
#     accuracy                           0.55      1764
#    macro avg       0.36      0.35      0.33      1764
# weighted avg       0.54      0.55      0.51      1764
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
#승무패를 처리하는 result_fnc0, 승1패를 처리하는 result_fnc1
from BaseballGameResult import result_fnc0, result_fnc1
#4차 모델링 WPA정보가 없는 경우 0, WPA이 0이하면 0
import pandas as pd
game_wpa0 = pd.read_csv('game_wpa_0.csv', encoding='cp949')
#print(game_war)
game_score = pd.read_csv('game_score.csv', encoding = 'cp949', header=None)
game_score.columns = ['경기', '결과']
#print(game_score)
df = pd.merge(game_wpa0, game_score , on='경기' )
df['결과'] = df.결과.apply(lambda x: int(x.split(':')[0])-int(x.split(':')[1]) )


#승1패
#df['결과'] = df.결과.apply(result_fnc1)
#승무패
df['결과'] = df.결과.apply(result_fnc0)

y = df.결과
x = df.drop(['경기','결과', 'Unnamed: 0'], axis=1)
print(x.head(10))
print(y.head(10))
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y)

from sklearn.preprocessing import StandardScaler
x_train = StandardScaler().fit_transform(x_train)
x_test = StandardScaler().fit_transform(x_test)

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C=100, max_iter=1000)
lr.fit(x_train, y_train)
pred = lr.predict(x_test)


from sklearn.metrics import classification_report
report = classification_report(y_test, pred)

#overfit
pred_over_fit = lr.predict(x_train)
report_over_fit = classification_report(y_train, pred_over_fit)

print(report)
print(report_over_fit)
# Out:
#    away_ 1루수  away_ 2루수  away_ 3루수  away_ 우익수  away_ 유격수  away_ 좌익수  \
# 0       1.72       0.50       0.00       1.04       0.00       0.00
# 1       1.09       0.36       0.00       0.01       0.00       0.00
# 2       0.35       0.80       0.29       0.45       0.72       0.11
# 3       1.09       0.36       0.00       0.01       0.00       0.00
# 4       0.35       0.80       0.29       0.45       0.72       0.11
# 5       1.09       0.36       0.00       0.01       0.00       0.00
# 6       0.69       1.08       0.36       0.00       0.55       0.12
# 7       1.09       0.36       0.00       0.78       0.00       0.00
# 8       1.09       0.36       0.00       0.78       0.00       0.00
# 9       0.30       0.01       0.96       0.00       0.16       0.82
#
#    away_ 중견수  away_ 투수  away_ 포수  away_1번타자  ...  home_ 포수  home_1번타자  \
# 0       0.56       0.0      0.02       0.50  ...      0.02       0.50
# 1       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 2       0.59       0.0      0.00       0.80  ...      0.00       0.80
# 3       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 4       0.59       0.0      0.00       0.80  ...      0.00       0.80
# 5       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 6       0.43       0.0      0.00       0.05  ...      0.00       0.05
# 7       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 8       0.79       0.0      0.23       0.36  ...      0.23       0.36
# 9       0.00       0.0      0.00       0.01  ...      0.00       0.01
#
#    home_2번타자  home_3번타자  home_4번타자  home_5번타자  home_6번타자  home_7번타자  \
# 0       0.56       1.04       1.72       0.00       0.00       0.02
# 1       0.00       0.79       0.73       1.09       0.00       0.00
# 2       0.11       0.59       0.35       0.72       0.29       0.00
# 3       0.00       0.79       0.73       1.09       0.00       0.00
# 4       0.11       0.59       0.35       0.72       0.29       0.45
# 5       0.00       0.79       0.73       1.09       0.00       0.00
# 6       0.00       1.08       0.69       0.43       0.12       0.55
# 7       0.78       0.79       0.73       1.09       0.00       0.00
# 8       0.78       0.79       0.73       1.09       0.00       0.00
# 9       0.00       0.30       0.82       0.96       0.64       0.00
#
#    home_8번타자  home_9번타자
# 0       0.00       0.00
# 1       0.23       0.01
# 2       0.45       0.00
# 3       0.23       0.01
# 4       0.33       0.00
# 5       0.23       0.01
# 6       0.36       0.00
# 7       0.00       0.23
# 8       0.00       0.23
# 9       0.00       0.16
#
# [10 rows x 36 columns]
# 0    home
# 1    away
# 2    away
# 3    home
# 4    home
# 5    home
# 6    away
# 7    away
# 8    home
# 9    away
# Name: 결과, dtype: object
#               precision    recall  f1-score   support
#
#         away       0.47      0.24      0.32       268
#         home       0.54      0.77      0.63       312
#         near       0.00      0.00      0.00         8
#
#     accuracy                           0.52       588
#    macro avg       0.34      0.34      0.32       588
# weighted avg       0.50      0.52      0.48       588
#
#               precision    recall  f1-score   support
#
#         away       0.53      0.26      0.35       787
#         home       0.57      0.82      0.67       957
#         near       0.00      0.00      0.00        20
#
#     accuracy                           0.56      1764
#    macro avg       0.36      0.36      0.34      1764
# weighted avg       0.54      0.56      0.52      1764
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\103-04\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
